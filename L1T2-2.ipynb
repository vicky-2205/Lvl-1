# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset.csv')

# %%
average_ratings_per_city = df.groupby('City')['Aggregate rating'].mean()

# %%
for city, average_rating in average_ratings_per_city.items():
    print(f'{city}: {average_rating:.2f}')
# Out:
# Abu Dhabi: 4.30
# Agra: 3.96
# Ahmedabad: 4.16
# Albany: 3.55
# Allahabad: 3.39
# Amritsar: 3.69
# Ankara: 4.31
# Armidale: 3.50
# Athens: 4.20
# Auckland: 4.27
# Augusta: 4.13
# Aurangabad: 3.37
# Balingup: 3.20
# Bandung: 4.20
# Bangalore: 4.38
# Beechworth: 4.60
# Bhopal: 3.95
# Bhubaneshwar: 3.98
# Birmingham: 3.68
# Bogor: 3.85
# Boise: 4.26
# Bras�_lia: 3.50
# Cape Town: 4.11
# Cedar Rapids/Iowa City: 4.17
# Chandigarh: 4.05
# Chatham-Kent: 3.70
# Chennai: 4.32
# Clatskanie: 4.30
# Cochrane: 3.10
# Coimbatore: 4.13
# Colombo: 3.87
# Columbus: 4.03
# Consort: 3.00
# Dalton: 4.11
# Davenport: 3.71
# Dehradun: 4.05
# Des Moines: 4.23
# Dicky Beach: 3.60
# Doha: 4.06
# Dubai: 4.37
# Dubuque: 3.54
# East Ballina: 4.10
# Edinburgh: 4.09
# Faridabad: 1.87
# Fernley: 3.70
# Flaxton: 3.50
# Forrest: 3.70
# Gainesville: 4.04
# Ghaziabad: 2.85
# Goa: 4.25
# Gurgaon: 2.65
# Guwahati: 4.19
# Hepburn Springs: 3.80
# Huskisson: 4.10
# Hyderabad: 4.34
# Indore: 3.97
# Inner City: 4.90
# ...
